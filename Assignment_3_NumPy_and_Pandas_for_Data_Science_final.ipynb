# %% [markdown]
# <a href="https://colab.research.google.com/github/Farukkibria/introduction/blob/main/Assignment_3_NumPy_and_Pandas_for_Data_Science_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Student Performance Dataset Analysis
Dataset Information
Student Performance Dataset (StudentsPerformance.csv)

1000 students with academic performance data
8 columns: gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score
Score Range: 0-100 for each subject
Demographics: Male/Female, 5 ethnic groups, 6 education levels, standard/free lunch, test prep completed/none
"""

# %%
#Task 1.1: Data Loading and Exploration
import numpy as np
import pandas as pd
from google.colab import files
uploaded = files.upload()

# Load the uploaded file
import io
df = pd.read_csv(io.BytesIO(uploaded['StudentsPerformancenew5.csv']))

# Load the dataset
#df = pd.read_csv('StudentsPerformance.csv')

# Your tasks:
# 1. Display first 10 rows
# 2. Show dataset shape and info()
# 3. Display unique values in each categorical column
# 4. Show basic statistics for all score columns

# Your code here:
print(df[1:10])
print("shape :", df.shape)
print("info", df.info)
print(df.describe())
# Out:
#      <input type="file" id="files-58f6448f-5b07-4afc-899f-7aa118f0943d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58f6448f-5b07-4afc-899f-7aa118f0943d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Task 1.2: NumPy Array Operations
# Convert score columns to numpy arrays
math_scores = df['math score'].values
reading_scores = df['reading score'].values
writing_scores = df['writing score'].values

# Your tasks:
# 1. Calculate mean, median, std, min, max for each subject using NumPy
# 2. Find total students who scored above 80 in math
# 3. Find total students who scored below 50 in any subject
# 4. Calculate the overall average score across all three subjects

# Expected output example:
# Math - Mean: 66.1, Median: 66.0, Std: 15.2
# Students with math > 80: 132
# Students with any score < 50: 178

# Your code here:
print("math scores info:\n")
print("mean:", np.mean(math_scores))
print("median:", np.median(math_scores))
print("std:", np.std(math_scores))
print("min:", np.min(math_scores))
print("max:", np.max(math_scores))
print("reading score info:")
print("mean:", np.mean(reading_scores))
print("median:", np.median(reading_scores))
print("std:", np.std(reading_scores))
print("min:", np.min(reading_scores))
print("max:", np.max(reading_scores))
print("writing scores info/n:")
print("mean:", np.mean(writing_scores))
print("median:", np.median(writing_scores))
print("std:", np.std(writing_scores))
print("min:", np.min(writing_scores))
print("max:", np.max(writing_scores))
math_ab_80=(math_scores>80)
print("total above 80 in math:",np.sum(math_ab_80))
math_bl_50=(math_scores<50)
print("total below 50 in math:",np.sum(math_bl_50))
reading_bl_50=(reading_scores<50)
print("total below 50 in reading:",np.sum(reading_bl_50))
writing_bl_50=(writing_scores<50)
print("total below 50 in writing:",np.sum(writing_bl_50))
total= np.sum(math_bl_50)+np.sum(reading_bl_50)+np.sum(writing_bl_50)
print("total below 50:", total)
tot=(np.mean(math_scores)+np.mean(reading_scores)+np.mean(writing_scores))/3
print("overall average score:",tot)
# Out:
# math scores info:
#
# mean: 66.089
# median: 66.0
# std: 15.155496659628149
# min: 0
# max: 100
# reading score info:
# mean: 69.169
# median: 70.0
# std: 14.592890015346516
# min: 17
# max: 100
# writing scores info/n:
# mean: 68.054
# median: 69.0
# std: 15.188057281956768
# min: 10
# max: 100
# total above 80 in math: 176
# total below 50 in math: 135
# total below 50 in reading: 90
# total below 50 in writing: 114
# total below 50: 339
# overall average score: 67.77066666666666

# %%
# Task 2.1: Identify and Handle Missing Data
# Check the dataset for any missing values
# Your tasks:
# 1. Check for null values in each column using .isnull().sum()
# 2. Check for any impossible values (scores > 100 or < 0)
# 3. Display summary of data quality

# Note: This dataset is clean, but let's verify!

# Your code here:
null_math=df['math score'].isnull().sum()
print(null_math)
null_reading=df['reading score'].isnull().sum()
print(null_reading)
null_writing=df['writing score'].isnull().sum()
print(null_writing)
impossible_values= (df['math score']<0) & (df['math score']>100).sum()
print ("\n impossible values:\n",impossible_values)
# Out:
# 0
# 0
# 0
#
#  impossible values:
#  0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: math score, Length: 1000, dtype: bool

# %%
#Task 2.2: Create and Fix Missing Value
# Artificially create missing data for practice
import numpy as np

# Your tasks:
# 1. Make a copy of the dataset: df_practice = df.copy()
# 2. Randomly set 50 math scores to np.nan
# 3. Randomly set 30 writing scores to np.nan
# 4. Fill missing math scores with the MEDIAN math score
# 5. Fill missing writing scores with the MEAN writing score
# 6. Verify no missing values remain

# Steps to follow:
# Step 1: Create copy and show original missing values
df_practice = df.copy()
print("Original missing values:", df_practice.isnull().sum())

# Step 2: Create missing data
np.random.seed(42)  # For reproducible results
missing_math_idx = np.random.choice(df_practice.index, 50, replace=False)
missing_writing_idx = np.random.choice(df_practice.index, 30, replace=False)
print("missing math",missing_math_idx)
print('missing writing',missing_writing_idx)
df_practice ["math score"]=df_practice ["math score"].replace(missing_math_idx,np.nan)
print('math score with nan',df_practice ["math score"])
df_practice ["math score"]=df_practice ["math score"].replace(np.nan,df_practice ["math score"].mean())
print('math score with avg',df_practice ["math score"])
df_practice ["writing score"]=df_practice ["writing score"].replace(missing_writing_idx,np.nan)
print('writing score with nan',df_practice ["writing score"])
df_practice ["writing score"]=df_practice ["writing score"].replace(np.nan,df_practice ["writing score"].mean())
print('writing score with avg',df_practice ["writing score"])
print("Final missing values:", df_practice.isnull().sum())
# Continue the task...
# Your code here:
# Out:
# Original missing values: gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64
# missing math [521 737 740 660 411 678 626 513 859 136 811  76 636 973 938 899 280 883
#  761 319 549 174 371 527 210 235 101 986 902 947 346 139 621 499 370 198
#  687 584 901  59 328  96 312 974 299 277 924 601 439 837]
# missing writing [ 93 692 100 562 729 924 393 685 738 264 172 314 870 983  70   9 361 444
#  857 855  90  47 812 861 456  56  66 469 967 420]
# math score with nan 0      72.0
# 1      69.0
# 2      90.0
# 3      47.0
# 4       NaN
#        ...
# 995    88.0
# 996    62.0
# 997     NaN
# 998    68.0
# 999    77.0
# Name: math score, Length: 1000, dtype: float64
# math score with avg 0      72.000000
# 1      69.000000
# 2      90.000000
# ...

# %%
#Task 3.1:Answer Simple Questions About Student Performance
# Your tasks:
# 1. Display first 5 rows using .head()
# 2. Display last 5 rows using .tail()
# 3. Show dataset shape using .shape
# 4. Show column names using .columns
# 5. Show data types using .dtypes
# 6. Show basic info using .info()

# Your code here:
print ("first 5 rows:\n", df.head())
print ("last 5 rows:\n", df.tail())
print ("shape:\n", df.shape)
print ("Math Score:\n", df["math score"])
print ("Reading Score:\n", df["reading score"])
print ("Writing Score:\n", df["writing score"])
print(df.columns)
print(df.dtypes)
print(df.info())
# Out:
# first 5 rows:
#     gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# last 5 rows:
#       gender race/ethnicity parental level of education         lunch  \
# ...

# %%
#Task 3.2: Basic Groupby Analysis
# Comprehensive groupby analysis
# Your tasks:

# 1. Group by 'gender' and calculate:
#    - Average scores in all subjects
#    - Count of students

# 2. Group by 'test preparation course' and show:
#    - Mean scores for each subject
#    - Show which subject benefits most from test prep

# 3. Group by 'parental level of education' and calculate:
#    - Average math score for each education level
#    - Rank education levels by math performance

# 4. Group by 'lunch' type and show:
#    - Average scores for each subject
#    - Count of students in each lunch category

# Your code here:
summary = df.groupby('gender')[['math score','reading score','writing score']].mean()
siz = df.groupby('gender')[['math score', 'reading score', 'writing score']].size()
print("Summary by gender:")
print(summary)
total_scor=summary.sum(axis=1)/3
print(total_scor)
print(siz)
summ = df.groupby('test preparation course')[['math score', 'reading score', 'writing score']].mean()
print("Summary by test preparation course:")
print(summ)
summa = df.groupby('parental level of education')[['math score']].mean()
print("Summary by parental level of education:")
print(summa)
ranking=summa.rank()
print("ranking:",ranking)
print("length", len(summa))
summar = df.groupby('lunch')[['math score', 'reading score', 'writing score']].mean()
summaryy = df.groupby('lunch')[['math score', 'reading score', 'writing score']].size()
print("Summary by launch provided:")
print(summar)
print(summaryy)
print ("Math average:",df['math score'].mean())
print ("Reading average:",df['reading score'].mean())
print ("Writing average:",df['writing score'].mean())
# Out:
# Summary by gender:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203
# gender
# female    69.569498
# male      65.837483
# dtype: float64
# gender
# female    518
# male      482
# dtype: int64
# Summary by test preparation course:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673
# Summary by parental level of education:
#                              math score
# parental level of education
# associate's degree            67.882883
# bachelor's degree             69.389831
# high school                   62.137755
# master's degree               69.745763
# some college                  67.128319
# some high school              63.497207
# ranking:                              math score
# ...

# %%
#Task 3.3: Use your data analysis skills to answer these easy questions:
summarr = df.groupby('parental level of education')[['math score','reading score', 'writing score']].mean()
total_score=summarr.sum(axis=1)/3
print(total_score)
# 1. Who performs better in math - males or females? male
#    - Calculate average math score by gender;  male=68.7, female=63.6
#    - Show the difference between male and female average; difference=5.1

# 2. Which subject do students perform best in overall?
#    - Calculate the overall average for math, reading, and writing; math=66.1; reading=69.1; writing=68.1
#    - Rank the subjects from highest to lowest average score; 1=reading; 2=writing; 3=Math

# 3. What's the impact of parental education?
#    - Find the average total score for each parental education level
#    - Identify which education level leads to highest student performance (masters degree)
# Out:
# parental level of education
# associate's degree    69.569069
# bachelor's degree     71.923729
# high school           63.096939
# master's degree       73.598870
# some college          68.476401
# some high school      65.108007
# dtype: float64
